# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = {"Professor\nBumble": 3, "Princess\nFluffybutt": 2, "Barnaby\nthe bear": 5}
names = list(data.keys())
values = list(data.values())

fig, ax = plt.subplots(figsize=(4, 3))
ax.grid(axis='y', linestyle='--', alpha=0.5, which='major')

bars = ax.bar(names, values, fill=None)

patterns = ['//', '.', '*', 'x', 'o', 'O', '+']
for bar, pattern in zip(bars, patterns):
    bar.set_hatch(pattern)

ax.set_yticks(np.arange(7))
ax.set_ylim(0, 6)
ax.set_ylabel('Blueberry Muffins', fontsize=14)
ax.set_title('Blueberry Muffins Eaten', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=14)
plt.show()

fig.savefig('43_muffins.pdf', bbox_inches='tight')

# %%
data = {"Ice\ncream": 3, "Cake": 2, "Candy": 5, "Cocoa": 1}
names = list(data.keys())
values = list(data.values())

fig, ax = plt.subplots(figsize=(4, 3))
ax.grid(axis='y', linestyle='--', alpha=0.5, which='major')

bars = ax.bar(names, values, fill=None)

patterns = ['//', '.', '*', 'x', 'o', 'O', '+']
for bar, pattern in zip(bars, patterns):
    bar.set_hatch(pattern)

ax.set_yticks(np.arange(7))
ax.set_ylim(0, 6)
ax.set_ylabel('Votes Cast', fontsize=14)
ax.set_title('Votes For Dessert', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=14)
plt.show()

fig.savefig('44_votes.pdf', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
import matplotlib.dates as mdates

# Integer hours of the day (0 to 23)
# Instead of simple integers, we'll create datetime objects to represent the hours
# An arbitrary date (July 20, 2025) is used, as only the time component is relevant for the plot.
start_time = datetime.datetime(2025, 7, 20, 0, 0, 0)
time_objects = [start_time + datetime.timedelta(hours=h) for h in range(24)]

# Corrected estimated Celsius temperatures for a typical Melbourne winter day
# These values now reflect a realistic pattern: coldest in early morning, warmest in afternoon.
temp = np.array([
    8,  # 00:00 (midnight)
    7,  # 01:00
    6,  # 02:00
    5,  # 03:00
    5,  # 04:00
    5,  # 05:00
    6,  # 06:00
    7,  # 07:00
    9,  # 08:00
    10, # 09:00
    11, # 10:00
    12, # 11:00
    13, # 12:00 (noon)
    14, # 13:00
    15, # 14:00
    14, # 15:00
    13, # 16:00
    11, # 17:00
    10, # 18:00
    9,  # 19:00
    9,  # 20:00
    8,  # 21:00
    8,  # 22:00
    8   # 23:00
])

# Create the plot
plt.figure(figsize=(4, 3)) # Set figure size to (4, 3) as requested

# Plot the data in black with circles as markers, using datetime objects for x-axis
plt.plot(time_objects, temp, color='black', marker='o', linestyle='-', linewidth=1, markersize=5)

# Add title and labels
plt.title('Forecast Temperature', color='black')
plt.ylabel('Temperature (°C)', color='black')

# Format the x-axis as time
# Use HourLocator to set ticks at specific intervals (e.g., every 4 hours)
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=4))
# Use DateFormatter to display time in h:mm AM/PM format
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%-I%p'))

# Rotate date labels for better readability if they overlap
#plt.gcf().autofmt_xdate()

# Add a grid for better readability, in light grey
plt.grid(True, linestyle='--', alpha=0.7, color='grey')

plt.savefig('45_temp.pdf', bbox_inches='tight')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
import matplotlib.dates as mdates

# Integer hours of the day (0 to 23)
# Instead of simple integers, we'll create datetime objects to represent the hours
# An arbitrary date (July 20, 2025) is used, as only the time component is relevant for the plot.
start_time = datetime.datetime(2025, 7, 20, 0, 0, 0)
time_objects = [start_time + datetime.timedelta(days=h) for h in range(7)]

# maximum daily temperatures
temp = np.array([15., 17, 18, 20, 19, 17, 17,]) # 18, 17, 17.])

# Create the plot
plt.figure(figsize=(4, 3)) # Set figure size to (4, 3) as requested

# Plot the data in black with circles as markers, using datetime objects for x-axis
plt.plot(time_objects, temp, color='black', marker='o', linestyle='-', linewidth=1, markersize=5)

# Add title and labels
plt.title('Forecast Maximum Daily Temperatures', color='black')
plt.ylabel('Temperature (°C)', color='black')

# Format the x-axis as time
# Use HourLocator to set ticks at specific intervals (e.g., every 4 hours)
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))
# Format as day name
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%A'))

# Rotate date labels for better readability if they overlap
plt.gcf().autofmt_xdate()

# Add a grid for better readability, in light grey
plt.grid(True, linestyle='--', alpha=0.7, color='grey')

plt.ylim([14, 21])

plt.savefig('46_temp.pdf', bbox_inches='tight')

plt.show()

# %%
from figures import create_bar_chart, create_pie_chart, create_line_chart

# --- Bar Chart Data and Creation ---
# 1. Favorite Animals
create_bar_chart(
    data=[8, 12, 3, 5],
    labels=['Cat', 'Dog', 'Fish', 'Bird'],
    title='Favourite Animals',
    filename='fig/bar_fav_animals.pdf',
    x_label=None,
    y_label='Count'
)

# 2. Number of Toys
create_bar_chart(
    data=[7, 5, 10, 4],
    labels=['Blocks', 'Stuffed', 'Cars', 'Figures'],
    title='My Toys',
    filename='fig/bar_my_toys.pdf',
    x_label=None,
    y_label='Count'
)

# 3. Colors of T-shirts
create_bar_chart(
    data=[6, 9, 4, 3, 2],
    labels=['Red', 'Blue', 'Green', 'Yellow', 'Other'],
    title='T-shirt Colors',
    filename='fig/bar_tshirt_colors.pdf',
    x_label=None,
    y_label='Count'
)

# 4. Fruit Eaten
create_bar_chart(
    data=[5, 7, 3, 6],
    labels=['Apple', 'Banana', 'Orange', 'Grape'],
    title='Fruit Eaten',
    filename='fig/bar_fruits_eaten.pdf',
    x_label=None,
    y_label='Count'
)

# 5. Books Read
create_bar_chart(
    data=[4, 6, 3, 5],
    labels=['Tom', 'Sara', 'Ben', 'Mia'],
    title='Books Read',
    filename='fig/bar_books_read.pdf',
    x_label=None,
    y_label='Books'
)

# --- Pie Chart Data and Creation ---
# 1. Breakfast Food Choices
create_pie_chart(
    data=[20, 15, 10, 5],
    labels=['Cereal', 'Toast', 'Eggs', 'Fruit'],
    title='Breakfast Food',
    filename='fig/pie_breakfast_food.pdf'
)

# 2. Ways We Get to School
create_pie_chart(
    data=[10, 8, 15, 3],
    labels=['Walk', 'Car', 'Bus', 'Bike'],
    title='Way of Getting to School',
    filename='fig/pie_to_school.pdf'
)

# 3. Favorite Ice Cream Flavors
create_pie_chart(
    data=[12, 18, 7, 3],
    labels=['Vanilla', 'Choc', 'Straw', 'Mint'],
    title='Favourite Ice Cream',
    filename='fig/pie_fav_ice_cream.pdf'
)

# 4. Activities Done in the Park
create_pie_chart(
    data=[15, 10, 8, 7],
    labels=['Swings', 'Slide', 'Run', 'Ball'],
    title='Park Fun',
    filename='fig/pie_park_fun.pdf'
)

# 5. Colors of Balloons at a Party
create_pie_chart(
    data=[10, 8, 6, 4],
    labels=['Red', 'Blue', 'Green', 'Yellow'],
    title='Balloons',
    filename='fig/pie_balloons.pdf'
)

# --- Line Chart Data and Creation ---
# 1. Plant Growth
create_line_chart(
    x_data=['Start', '1', '2', '3', '4'],
    y_data=[0, 2, 4, 7, 9],
    title='Plant Growth (cm)',
    x_label='Week',
    y_label='Height (cm)',
    filename='fig/line_plant_growth.pdf'
)

# 2. Temperature Throughout the Day
create_line_chart(
    x_data=['6am', '9am', '12pm', '3pm', '6pm'],
    y_data=[15, 18, 22, 20, 17],
    title='Temp Today (°C)',
    x_label=None,
    y_label='Temp (°C)',
    filename='fig/line_temp_today.pdf'
)

# 3. Number of Pages Read Each Day
create_line_chart(
    x_data=['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5'],
    y_data=[10, 15, 8, 12, 18],
    title='Pages Read',
    x_label=None,
    y_label='Pages',
    filename='fig/line_pages_read.pdf'
)

# 4. Pencil Sharpenings
create_line_chart(
    x_data=['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    y_data=[3, 2, 4, 1, 3],
    title='Times Peter Sharpened Pencil',
    x_label=None,
    y_label='Times Sharpened',
    filename='fig/line_pencil_sharpenings.pdf'
)

# 5. Time Spent Playing Outside
create_line_chart(
    x_data=['Day 1', 'Day 2', 'Day 3', 'Day 4'],
    y_data=[30, 45, 20, 50],
    title='Outside Play (min)',
    x_label=None,
    y_label='Minutes',
    filename='fig/line_outside_play.pdf'
)

create_line_chart(
    x_data=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'],
    y_data=[30, 45, 20, 50, 30, 0, 15],
    title='Play time at the park',
    x_label=None,
    y_label='Minutes',
    filename='fig/play_at_park.pdf'
)

# %%
from figures import draw_clock
import matplotlib.pyplot as plt

times_to_draw = [
    (1, 0, 12), (5, 0, 45), (9, 0, 37), (12, 0, 11), (18, 0, 23),
    (6, 30, 41), (2, 45, 10), (10, 15, 11), (7, 30, 28), (11, 45, 42),
    (4, 35, 22), (8, 10, 36), (3, 55, 12), (1, 20, 14), (7, 5, 6),
    (10, 50, 22), (12, 25, 1), (2, 40, 13), (5, 15, 12), (9, 35, 14),
    (1, 10, 12), (5, 30, 45), (9, 10, 37), (12, 30, 11), (18, 10, 23),
    (6, 45, 41), (2, 55, 10), (10, 25, 11), (7, 45, 28), (11, 55, 42),
    (4, 45, 22), (8, 20, 36), (3, 65, 12), (1, 30, 14), (7, 15, 6),
    (10, 60, 22), (12, 35, 1), (2, 50, 13), (5, 25, 12), (9, 45, 14)
]

# Draw clocks and save to PDF
for hour, minute, second in times_to_draw:
    fig, ax = plt.subplots(figsize=(4, 4))
    draw_clock(hour, minute, second, ax=ax)
    filename = f'fig/clock_{hour:02d}{minute:02d}.pdf'
    fig.savefig(filename, bbox_inches='tight')
    plt.close(fig)

# %%
fig, axes = plt.subplots(4, 3, figsize=(10, 12))

for i, ax in enumerate(axes.ravel(), 0):
    ax.set_aspect('equal', adjustable='box')
    # ax.set_xlim([-1.2, 1.2])
    # ax.set_ylim([-1.2, 1.2])
    # ax.set_axis_off()
    # ax.text(0, 0, f'{i+1}', fontsize=12, ha='center', va='center')
    draw_clock(5, i*5, (14 + i*27) % 60, ax=ax)
    ax.set_title('5:________', fontsize=16)

plt.savefig('fig/clock_grid_0500.pdf', bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/IDCJAC0002_066037_Data1.csv')
df.columns = ['code', 'station', 'year', 'month', 'max_temp', 'quality']
df['day'] = 1
df['date'] = pd.to_datetime(df[['year', 'month', 'day']])

#df = df.groupby('date').agg({'max_temp': 'mean'}).reset_index()

fig, ax = plt.subplots(figsize=(12, 3))
ax.plot(df['date'], df['max_temp'], linestyle='-', color='black', linewidth=1)
ax.set_ylabel('Temperature (°C)', fontsize=12)
ax.set_xlabel('Date', fontsize=12)
ax.set_title('Maximum Temperature in Sydney Airport', fontsize=12)
ax.grid(True, linestyle='--', alpha=0.7, color='grey')

# plt.savefig('fig/line_max_temp.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(12, 4))
df_jun = df[df['month'] == 6]
df_jan = df[df['month'] == 1]
ax.plot(df_jan['date'], df_jan['max_temp'], linestyle=':', color='red', linewidth=1, label='January')
ax.plot(df_jun['date'], df_jun['max_temp'], linestyle='-', color='black', linewidth=1, label='June')
ax.legend(fontsize=12, frameon=True)
ax.set_ylabel('Temperature (°C)', fontsize=12)
ax.set_title('Average Maximum Monthly Temperature, Sydney Airport', fontsize=12)
ax.grid(True, linestyle='--', alpha=0.5, color='grey')
ax.set_yticks(range(14, 32, 2))
fig.tight_layout()

fig.savefig('fig/line_max_monthly_temp_syd.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(12, 4))
df = pd.read_csv('data/seatac.csv')
ax.plot(df['Year'], 5/9*(df['Jan']-32), linestyle=':', color='red', linewidth=1, label='January')
ax.plot(df['Year'], 5/9*(df['Jun']-32), linestyle='-', color='black', linewidth=1, label='June')
ax.legend(fontsize=12, frameon=True)
ax.set_ylabel('Temperature (°C)', fontsize=12)
ax.set_title('Average Monthly Temperature, Seattle-Tacoma Airport', fontsize=12)
ax.grid(True, linestyle='--', alpha=0.5, color='grey')
#ax.set_yticks(range(14, 32, 2))
fig.tight_layout()

fig.savefig('fig/line_monthly_temp_sea.pdf', bbox_inches='tight')

# %%
df.head()
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1945.0  41.9  42.2  43.2  46.7  57.0  58.8  65.3  63.8  56.7  52.4  43.2
# 1  1946.0  39.3  41.3  43.2  47.9  57.2  58.1  64.5  63.6  58.7  47.7  40.6
# 2  1947.0  35.0  43.9  47.6  51.1  57.8  59.8  63.6  62.8  59.1  51.9  43.1
# 3  1948.0  38.0  38.9  42.9  45.5  52.9  61.7  62.4  61.2  57.1  50.4  42.1
# 4  1949.0  29.9  37.3  45.5  50.1  57.3  59.1  62.6  63.7  60.8  48.6  49.4
#
#     Dec
# 0  39.0
# 1  38.9
# 2  42.0
# 3  36.0
# 4  38.4

# %%
rs = pd.read_csv('data/abs_monthly_retail_sales.csv')
rs['month'] = pd.to_datetime(rs['month'])
rs = rs.set_index('month')
rs.tail()
# Out:
#             food_retailing  household_goods_retailing  \
# month
# 2025-02-01         13589.6                     5174.1
# 2025-03-01         15149.9                     5535.1
# 2025-04-01         14530.8                     5294.2
# 2025-05-01         14747.0                     5703.8
# 2025-06-01         14095.0                     6187.5
#
#             clothing_footwear_and_personal_accessory_retailing  \
# month
# 2025-02-01                                             2457.1
# 2025-03-01                                             2809.2
# 2025-04-01                                             2816.1
# 2025-05-01                                             3167.1
# 2025-06-01                                             3065.3
#
#             department_stores  other_retailing  \
# month
# 2025-02-01             1435.0           5122.6
# 2025-03-01             1732.7           5567.2
# 2025-04-01             1774.5           5476.2
# ...

# %%
# plot data in rs
fig, ax = plt.subplots(figsize=(12, 4))
rs2019 = rs[rs.index >= pd.to_datetime('2019-01-01')]
ax.plot(rs2019.index, 1e-3*rs2019['total'], marker='o', color='black', linewidth=1)
ax.set_ylabel('$ billions', fontsize=12)
ax.set_title('Total Monthly Retail Sales, Australia', fontsize=12)
ax.grid(True, linestyle='--', alpha=0.5, color='grey')
ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1,7]))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%B\n%Y'))
fig.tight_layout()

fig.savefig('fig/line_retail_sales.pdf', bbox_inches='tight')

# %%
# plot data in rs
fig, ax = plt.subplots(figsize=(12, 5))
rs2019 = rs[rs.index >= pd.to_datetime('2019-01-01')]
ax.plot(rs2019.index, 1e-3*rs2019['food_retailing'], linewidth=2, linestyle=':', marker='+', label='Food retailing (supermarkets, grocery stores, etc.)')
ax.plot(rs2019.index, 1e-3*rs2019['cafes_restaurants_and_takeaway_food_services'], linewidth=2, linestyle='-', marker='+', label='Cafes, restaurants and takeaway food')
ax.legend(fontsize=12, loc='upper left', frameon=False)
ax.set_ylabel('$ billions', fontsize=12)
ax.set_title('Monthly Retail Sales, Australia', fontsize=16)
ax.grid(True, linestyle='--', alpha=0.5, color='grey')
ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1,7]))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%B\n%Y'))
#plt.xticks(rotation=45)

fig.tight_layout()

fig.savefig('fig/line_retail_sales_food.pdf', bbox_inches='tight')

# %%
#! wget https://dataandreporting.blob.core.windows.net/anrdataportal/Data-Access-Program/Enrolments%20by%20Grade%202008-2024.xlsx
import pandas as pd
import os

if not os.path.exists('data/pvps_enrolments.csv'):
    df = pd.read_excel('Enrolments by Grade 2008-2024.xlsx', sheet_name='EnrolmentsByGrade 2008-2024')

    df = df[df['School Name'] == 'Pascoe Vale Primary School']
    df['Year'] = df['Calendar Year'].astype(int)
    df['Foundation'] = df['One year before Year 1 Enrolments']
    df['Grade 1/2'] = df['Year 1 Enrolments'] + df['Year 2 Enrolments']
    df['Grade 3/4'] = df['Year 3 Enrolments'] + df['Year 4 Enrolments']
    df['Grade 5/6'] = df['Year 5 Enrolments'] + df['Year 6 Enrolments']
    cs = ['Year', 'Foundation', 'Grade 1/2', 'Grade 3/4', 'Grade 5/6']
    df = df[cs]
    df.to_csv('bin/pvps_enrolments.csv', index=False)
else:
    df = pd.read_csv('data/pvps_enrolments.csv')

df.head()
# Out:
#    Year  Foundation  Grade 1/2  Grade 3/4  Grade 5/6
# 0  2024        71.0      134.0      150.0      157.0
# 1  2023        65.0      140.0      153.0      164.0
# 2  2022        71.0      158.0      163.0      151.0
# 3  2021        78.0      166.0      181.0      156.0
# 4  2020        95.0      183.0      181.0      136.0

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 4 ))

df['Total'] = df['Foundation'] + df['Grade 1/2'] + df['Grade 3/4'] + df['Grade 5/6']

ax.plot(df['Year'], df['Total'], linewidth=2)

ax.set_ylabel('Students', fontsize=16)
ax.set_title('Pascoe Vale Primary School: Enrolments', fontsize=16)
ax.grid(True, linestyle='--', alpha=0.5)

plt.show()
fig.savefig('fig/pvps_enrolments.pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 4 ))

for col, ls in [('Foundation', '-'), ('Grade 1/2', '--'), ('Grade 3/4', ':'), ('Grade 5/6', '-.')]:
    ax.plot(df['Year'], df[col], label=col, linewidth=2, linestyle=ls)

ax.legend()
ax.set_ylabel('Students', fontsize=16)
ax.set_title('Pascoe Vale Primary School: Enrolments', fontsize=16)
ax.grid(True, linestyle='--', alpha=0.5)

plt.show()
fig.savefig('fig/pvps_enrolments_grade.pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5, 4 ))

df2024 = df[df['Year'] == 2024][df.columns[1:]]
ax.bar(list(df2024.columns), list(df2024.values[0]), fill=None, edgecolor='black', hatch='//')
ax.set_ylabel('Students', fontsize=16)
ax.set_title('Pascoe Vale Primary School\n2024 Enrolments', fontsize=16)
ax.grid(True, axis='y', linestyle='--', alpha=0.5)
ax.set_ylim(0, 180)

plt.show()
fig.savefig('fig/pvps_enrolments_grade_2024.pdf', bbox_inches='tight')

# %%
df = pd.read_excel('Enrolments by Grade 2008-2024.xlsx', sheet_name='EnrolmentsByGrade 2008-2024')
# Out:
# /home/acooper/src/worksheets/.venv/lib/python3.12/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: Table13[#All].
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")

# %%
def cohorts_for_school(df, school_name, ax=None):
    if ax is None:
        _, ax = plt.subplots(figsize=(8,4))

    df = df[df['School Name'] == school_name].copy()
    df['Year'] = df['Calendar Year'].astype(int)

    cohorts_y6 = range(2009, 2031)
    cohorts = {c: [None] * 7 for c in cohorts_y6}
    cohorts_years = {c: [None] * 7 for c in cohorts_y6}
    grademap = {f'Year {i} Enrolments': i for i in range(1, 7)} | {'One year before Year 1 Enrolments': 0}
    for cohort in cohorts_y6:
        for key, grade in grademap.items():
            year = cohort - 6 + grade
            if year >= 2008 and year < 2025:
                cohorts[cohort][grade] = float(df[df['Year'] == year][key].values[0])
                cohorts_years[cohort][grade] = year
        cohorts[cohort] = np.array(cohorts[cohort], dtype=np.float32)
        cohorts_years[cohort] = np.array(cohorts_years[cohort], dtype=np.float32)

    for cohort in range(2009, 2031):
        ax.plot(cohorts_years[cohort], cohorts[cohort], marker='o', label=f"Class of {cohort}")
    #ax.legend()
    ax.set_xlim(2009, 2025)
    ax.set_ylabel('Enrolments', fontsize=16)
    ax.set_title(f'{school_name}', fontsize=16)
    ax.grid(True, linestyle='--', alpha=0.5)
    return ax

fig, ax = plt.subplots(figsize=(8,4))
cohorts_for_school(df, 'Pascoe Vale Primary School', ax=ax)
ax.set_title('Pascoe Vale Primary School\nEnrolments by Cohort', fontsize=16)
fig.tight_layout()
fig.savefig('fig/pvps_enrolments_cohort.pdf', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8), sharey=True, sharex=True)
for ax, school_name in zip(axes.flatten(), ['Pascoe Vale Primary School',
 'Pascoe Vale South Primary School',
 'Pascoe Vale North Primary School',
 "St Oliver Plunkett's School"]):
    cohorts_for_school(df, school_name, ax=ax)
fig.tight_layout()
fig.savefig('fig/pv_enrolments_cohort.pdf', bbox_inches='tight')
