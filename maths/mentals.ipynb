# %%
number = 48

import random
random.seed(number)

mentals = set[str]()

while len(mentals) < 12:
    x = random.randint(0, 12)
    y = random.randint(0, 12)
    if random.random() < 0.75:
        if x not in [0, 1, 2, 10] and y not in [0, 1, 2, 10]:
            continue
        mentals.add(f"${x} \\times {y}=$")
    else:
        mentals.add(f"${x} + {y}=$")

mental_list = list(mentals)
random.shuffle(mental_list)

# %%
print(f"\clearpage\section{{Problem set \textnumero {number}}}")
print("\\begin{enumerate}")
print("\\item")
print("\\begin{multicols}{3}")
print("\\begin{enumerate}")
percol = len(mental_list) // 3
for i, m in enumerate(mental_list):
    maybe_skip = "" if (i+1) % percol == 0 else "\\bigskip"
    print(f"      \\item {m} \\dotfill{maybe_skip}")
print("\\end{enumerate}")
print("\\end{multicols}")

print("\\end{enumerate}")
# Out:
# \clearpage\section{Problem set 	extnumero 48}
# \begin{enumerate}
# \item
# \begin{multicols}{3}
# \begin{enumerate}
#       \item $6 \times 2=$ \dotfill\bigskip
#       \item $10 \times 3=$ \dotfill\bigskip
#       \item $8 + 8=$ \dotfill\bigskip
#       \item $3 + 6=$ \dotfill
#       \item $2 \times 7=$ \dotfill\bigskip
#       \item $1 \times 3=$ \dotfill\bigskip
#       \item $10 + 0=$ \dotfill\bigskip
#       \item $7 \times 10=$ \dotfill
#       \item $1 \times 6=$ \dotfill\bigskip
#       \item $12 \times 10=$ \dotfill\bigskip
#       \item $2 \times 0=$ \dotfill\bigskip
#       \item $5 \times 10=$ \dotfill
# \end{enumerate}
# \end{multicols}
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_118060/2891702513.py:1: SyntaxWarning: invalid escape sequence '\c'
#   print(f"\clearpage\section{{Problem set \textnumero {number}}}")
